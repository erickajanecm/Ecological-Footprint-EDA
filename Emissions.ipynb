# %% [markdown]
# <h3> Carbon Emission of Each Country from 1949-2017

# %%
#Importing all necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Loading the dataset
Emission_DF = pd.read_csv('CO2_Emissions_2017.csv')
Emission_DF.head()
# Out:
#   Carbon Dioxide emissions from fossil fuel consumption and cement production by nation  \
# 0  D.  Gilfillan, G.  Marland, T.  Boden, and R. ...
# 1  Carbon dioxide emissions by country from 1751 ...
# 2                                                NaN
# 3                                             Nation
# 4                                       AFGHANISTAN
#
#   Unnamed: 1                                         Unnamed: 2  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3       Year  Total CO2 emissions from fossil-fuels and ceme...
# 4       1949                                                  4
#
#                               Unnamed: 3  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3  Emissions from solid fuel consumption
# ...

# %%
#Looking for the columns
Emission_DF.columns
# Out:
# Index(['Carbon Dioxide emissions from fossil fuel consumption and cement production by nation',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
#Looking for the shape of the dataframe
Emission_DF.shape
# Out:
# (17932, 10)

# %% [markdown]
# We have to change the data types of some columns from 'object' to 'float'

# %%
#Resetting the column names
Emission_DF.columns = Emission_DF.iloc[3]
Emission_DF.head()
# Out:
# 3                                             Nation  Year  \
# 0  D.  Gilfillan, G.  Marland, T.  Boden, and R. ...   NaN
# 1  Carbon dioxide emissions by country from 1751 ...   NaN
# 2                                                NaN   NaN
# 3                                             Nation  Year
# 4                                       AFGHANISTAN   1949
#
# 3 Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Total CO2 emissions from fossil-fuels and ceme...
# 4                                                  4
#
# 3  Emissions from solid fuel consumption  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3  Emissions from solid fuel consumption
# ...

# %%
#Deleting the unneccesary rows
Emission_DF.drop(Emission_DF.index[0:3], inplace=True)

# %%
Emission_DF.head()
# Out:
# 3        Nation  Year  \
# 3        Nation  Year
# 4  AFGHANISTAN   1949
# 5  AFGHANISTAN   1950
# 6  AFGHANISTAN   1951
# 7  AFGHANISTAN   1952
#
# 3 Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 3  Total CO2 emissions from fossil-fuels and ceme...
# 4                                                  4
# 5                                                 23
# 6                                                 25
# 7                                                 25
#
# 3  Emissions from solid fuel consumption  \
# 3  Emissions from solid fuel consumption
# 4                                      4
# 5                                      6
# 6                                      7
# 7                                      9
#
# 3  Emissions from liquid fuel consumption  \
# 3  Emissions from liquid fuel consumption
# 4                                       0
# 5                                      18
# ...

# %%
Emission_DF.nunique()
# Out:
# 3
# Nation                                                                                      260
# Year                                                                                        268
# Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)    8266
# Emissions from solid fuel consumption                                                      5628
# Emissions from liquid fuel consumption                                                     5905
# Emissions from gas fuel consumption                                                        3485
# Emissions from cement production                                                           2230
# Emissions from gas flaring                                                                 1334
# Per capita CO2 emissions (metric tons of carbon)                                            818
# Emissions from bunker fuels (not included in the totals)                                   2429
# dtype: int64

# %%
Emission_DF.columns.name = ''

# %%
Emission_DF.head()
# Out:
#          Nation  Year  \
# 3        Nation  Year
# 4  AFGHANISTAN   1949
# 5  AFGHANISTAN   1950
# 6  AFGHANISTAN   1951
# 7  AFGHANISTAN   1952
#
#   Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 3  Total CO2 emissions from fossil-fuels and ceme...
# 4                                                  4
# 5                                                 23
# 6                                                 25
# 7                                                 25
#
#    Emissions from solid fuel consumption  \
# 3  Emissions from solid fuel consumption
# 4                                      4
# 5                                      6
# 6                                      7
# 7                                      9
#
#    Emissions from liquid fuel consumption  \
# 3  Emissions from liquid fuel consumption
# 4                                       0
# 5                                      18
# ...

# %%
Emission_DF.reset_index()
# Out:
#        index        Nation  Year  \
# 0          3        Nation  Year
# 1          4  AFGHANISTAN   1949
# 2          5  AFGHANISTAN   1950
# 3          6  AFGHANISTAN   1951
# 4          7  AFGHANISTAN   1952
# ...      ...           ...   ...
# 17924  17927     ZIMBABWE   2013
# 17925  17928     ZIMBABWE   2014
# 17926  17929     ZIMBABWE   2015
# 17927  17930     ZIMBABWE   2016
# 17928  17931     ZIMBABWE   2017
#
#       Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 0      Total CO2 emissions from fossil-fuels and ceme...
# 1                                                      4
# 2                                                     23
# 3                                                     25
# 4                                                     25
# ...                                                  ...
# 17924                                               3176
# 17925                                               3272
# ...

# %%
Emission_DF.drop(Emission_DF.index[0])
# Out:
#              Nation  Year  \
# 4      AFGHANISTAN   1949
# 5      AFGHANISTAN   1950
# 6      AFGHANISTAN   1951
# 7      AFGHANISTAN   1952
# 8      AFGHANISTAN   1953
# ...             ...   ...
# 17927     ZIMBABWE   2013
# 17928     ZIMBABWE   2014
# 17929     ZIMBABWE   2015
# 17930     ZIMBABWE   2016
# 17931     ZIMBABWE   2017
#
#       Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 4                                                      4
# 5                                                     23
# 6                                                     25
# 7                                                     25
# 8                                                     29
# ...                                                  ...
# 17927                                               3176
# 17928                                               3272
# 17929                                               3324
# ...

# %%
Emission_DF.columns
# Out:
# Index(['Nation', 'Year',
#        'Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)',
#        'Emissions from solid fuel consumption',
#        'Emissions from liquid fuel consumption',
#        'Emissions from gas fuel consumption',
#        'Emissions from cement production', 'Emissions from gas flaring',
#        'Per capita CO2 emissions (metric tons of carbon)',
#        'Emissions from bunker fuels (not included in the totals)'],
#       dtype='object', name='')

# %%
Emission_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17929 entries, 3 to 17931
# Data columns (total 10 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Nation                                                                                   17929 non-null  object
#  1   Year                                                                                     17929 non-null  object
#  2   Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  17929 non-null  object
#  3   Emissions from solid fuel consumption                                                    17929 non-null  object
#  4   Emissions from liquid fuel consumption                                                   17929 non-null  object
# ...

# %%
Emission_DF.drop(Emission_DF.index[0], inplace=True)

# %%
#Capitalizing the values in 'Nation' columns
Emission_DF['Nation'] = [x.upper() for x in Emission_DF['Nation']]
Emission_DF['Nation']
# Out:
# 4        AFGHANISTAN
# 5        AFGHANISTAN
# 6        AFGHANISTAN
# 7        AFGHANISTAN
# 8        AFGHANISTAN
#              ...
# 17927       ZIMBABWE
# 17928       ZIMBABWE
# 17929       ZIMBABWE
# 17930       ZIMBABWE
# 17931       ZIMBABWE
# Name: Nation, Length: 17928, dtype: object

# %%
Emission_DF['Nation'] = [x.strip() for x in Emission_DF['Nation']]

# %%
#Checking if the Philippines have record in the dataframe
Emission_DF[Emission_DF['Nation'] == 'PHILIPPINES']
# Out:
#             Nation  Year  \
# 12317  PHILIPPINES  1907
# 12318  PHILIPPINES  1908
# 12319  PHILIPPINES  1909
# 12320  PHILIPPINES  1910
# 12321  PHILIPPINES  1911
# ...            ...   ...
# 12420  PHILIPPINES  2013
# 12421  PHILIPPINES  2014
# 12422  PHILIPPINES  2015
# 12423  PHILIPPINES  2016
# 12424  PHILIPPINES  2017
#
#       Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 12317                                                  2
# 12318                                                  5
# 12319                                                 15
# 12320                                                 14
# 12321                                                 10
# ...                                                  ...
# 12420                                              26274
# 12421                                              27738
# 12422                                              30730
# ...

# %%
#CREATING A DATAFRAME FOR 'PHILIPPINES'

PH_Emission_DF = Emission_DF[Emission_DF['Nation'] == 'PHILIPPINES']
PH_Emission_DF
# Out:
#             Nation  Year  \
# 12317  PHILIPPINES  1907
# 12318  PHILIPPINES  1908
# 12319  PHILIPPINES  1909
# 12320  PHILIPPINES  1910
# 12321  PHILIPPINES  1911
# ...            ...   ...
# 12420  PHILIPPINES  2013
# 12421  PHILIPPINES  2014
# 12422  PHILIPPINES  2015
# 12423  PHILIPPINES  2016
# 12424  PHILIPPINES  2017
#
#       Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 12317                                                  2
# 12318                                                  5
# 12319                                                 15
# 12320                                                 14
# 12321                                                 10
# ...                                                  ...
# 12420                                              26274
# 12421                                              27738
# 12422                                              30730
# ...
