# %% [markdown]
# <h2>World - Biocapacity vs Ecological Footprint (gha per person)

# %%
#Importing necessary libraries
import pandas as pd

# %%
# Loading the data
World_EF = pd.read_csv('./Ecological Footprint vs Biocapacity (gha per person).csv')
World_EF.head()
# Out:
#   Country Name Short Name  year        Record  Built-up Land    Carbon  \
# 0        World    º World  1961  BiocapPerCap       0.027316  0.000000
# 1        World    º World  1961  EFConsPerCap       0.027316  0.994391
# 2        World    º World  1962  BiocapPerCap       0.028128  0.000000
# 3        World    º World  1962  EFConsPerCap       0.028128  1.018199
# 4        World    º World  1963  BiocapPerCap       0.028290  0.000000
#
#    Cropland  Fishing Grounds  Forest Products  Grazing Land     Total  \
# 0  0.471736         0.360253         1.812765      0.477855  3.149925
# 1  0.471736         0.093879         0.426056      0.263728  2.277104
# 2  0.477944         0.352989         1.777278      0.469172  3.105510
# 3  0.477944         0.096409         0.421570      0.261271  2.303520
# 4  0.474250         0.345810         1.739197      0.459991  3.047538
#
#   Data Quality Score      isoa2
# 0                 3A  undefined
# 1                 3A  undefined
# ...

# %%
# Shape of the dataframe
World_EF.shape
# Out:
# (116, 13)

# %%
# Columns of the dataframe
World_EF.columns
# Out:
# Index(['Country Name', 'Short Name', 'year', 'Record', 'Built-up Land',
#        'Carbon', 'Cropland', 'Fishing Grounds', 'Forest Products',
#        'Grazing Land', 'Total', 'Data Quality Score', 'isoa2'],
#       dtype='object')

# %% [markdown]
# There are columns in this dataframe that are not necessary for our analysis so we have to drop them.

# %%
# Information about the dataframe
World_EF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country Name        116 non-null    object
#  1   Short Name          116 non-null    object
#  2   year                116 non-null    int64
#  3   Record              116 non-null    object
#  4   Built-up Land       116 non-null    float64
#  5   Carbon              116 non-null    float64
#  6   Cropland            116 non-null    float64
#  7   Fishing Grounds     116 non-null    float64
#  8   Forest Products     116 non-null    float64
#  9   Grazing Land        116 non-null    float64
#  10  Total               116 non-null    float64
#  11  Data Quality Score  116 non-null    object
#  12  isoa2               116 non-null    object
# dtypes: float64(7), int64(1), object(5)
# memory usage: 11.9+ KB

# %% [markdown]
# <h4> Transformation

# %%
#Dropping the unnecessary columns
cols_to_drop = ['Country Name', 'Short Name', 'Data Quality Score', 'isoa2']
World_EF.drop(cols_to_drop, axis=1, inplace=True)

World_EF
# Out:
#      year        Record  Built-up Land    Carbon  Cropland  Fishing Grounds  \
# 0    1961  BiocapPerCap       0.027316  0.000000  0.471736         0.360253
# 1    1961  EFConsPerCap       0.027316  0.994391  0.471736         0.093879
# 2    1962  BiocapPerCap       0.028128  0.000000  0.477944         0.352989
# 3    1962  EFConsPerCap       0.028128  1.018199  0.477944         0.096409
# 4    1963  BiocapPerCap       0.028290  0.000000  0.474250         0.345810
# ..    ...           ...            ...       ...       ...              ...
# 111  2016  EFConsPerCap       0.062363  1.612516  0.513836         0.088009
# 112  2017  BiocapPerCap       0.063750  0.000000  0.523323         0.142324
# 113  2017  EFConsPerCap       0.063750  1.672306  0.523323         0.089443
# 114  2018  BiocapPerCap       0.063250  0.000000  0.513460         0.140916
# 115  2018  EFConsPerCap       0.063250  1.689557  0.513460         0.089534
#
#      Forest Products  Grazing Land     Total
# ...

# %%
# Renaming the column 'year' - (capitalization)
World_EF.columns = World_EF.columns.str.replace('year', 'Year')

World_EF
# Out:
#      Year        Record  Built-up Land    Carbon  Cropland  Fishing Grounds  \
# 0    1961  BiocapPerCap       0.027316  0.000000  0.471736         0.360253
# 1    1961  EFConsPerCap       0.027316  0.994391  0.471736         0.093879
# 2    1962  BiocapPerCap       0.028128  0.000000  0.477944         0.352989
# 3    1962  EFConsPerCap       0.028128  1.018199  0.477944         0.096409
# 4    1963  BiocapPerCap       0.028290  0.000000  0.474250         0.345810
# ..    ...           ...            ...       ...       ...              ...
# 111  2016  EFConsPerCap       0.062363  1.612516  0.513836         0.088009
# 112  2017  BiocapPerCap       0.063750  0.000000  0.523323         0.142324
# 113  2017  EFConsPerCap       0.063750  1.672306  0.523323         0.089443
# 114  2018  BiocapPerCap       0.063250  0.000000  0.513460         0.140916
# 115  2018  EFConsPerCap       0.063250  1.689557  0.513460         0.089534
#
#      Forest Products  Grazing Land     Total
# ...

# %% [markdown]
# <h4> Separating the 'BiocapPerCap' and 'EFConsPerCap' in the 'Record' column

# %%
# EFConsPerCap
EF_DF = World_EF.loc[World_EF['Record'] == 'EFConsPerCap']

EF_DF.head()
# Out:
#    Year        Record  Built-up Land    Carbon  Cropland  Fishing Grounds  \
# 1  1961  EFConsPerCap       0.027316  0.994391  0.471736         0.093879
# 3  1962  EFConsPerCap       0.028128  1.018199  0.477944         0.096409
# 5  1963  EFConsPerCap       0.028290  1.069135  0.474250         0.097743
# 7  1964  EFConsPerCap       0.028978  1.117176  0.477281         0.094064
# 9  1965  EFConsPerCap       0.029337  1.153521  0.475675         0.099426
#
#    Forest Products  Grazing Land     Total
# 1         0.426056      0.263728  2.277104
# 3         0.421570      0.261271  2.303520
# 5         0.417479      0.261788  2.348685
# 7         0.424122      0.254985  2.396608
# 9         0.420272      0.256638  2.434866

# %%
# BiocapPerCap
Biocapacity_DF = World_EF.loc[World_EF['Record'] == 'BiocapPerCap']
Biocapacity_DF.head()
# Out:
#    Year        Record  Built-up Land  Carbon  Cropland  Fishing Grounds  \
# 0  1961  BiocapPerCap       0.027316     0.0  0.471736         0.360253
# 2  1962  BiocapPerCap       0.028128     0.0  0.477944         0.352989
# 4  1963  BiocapPerCap       0.028290     0.0  0.474250         0.345810
# 6  1964  BiocapPerCap       0.028978     0.0  0.477281         0.338812
# 8  1965  BiocapPerCap       0.029337     0.0  0.475675         0.331793
#
#    Forest Products  Grazing Land     Total
# 0         1.812765      0.477855  3.149925
# 2         1.777278      0.469172  3.105510
# 4         1.739197      0.459991  3.047538
# 6         1.704897      0.451605  3.001574
# 8         1.669230      0.443618  2.949653

# %% [markdown]
# <h4>Visualze the status of biocapacity and ecological footprint throughout the years

# %%
#Importing libraries
import matplotlib.pyplot as plt
import numpy as np

x = Biocapacity_DF['Total'] 
year = np.arange(1961, 2019)
y = EF_DF['Total']
fig = plt.figure(figsize=(15, 8))
plt.plot(year, x, color='green')
plt.plot(year, y, color='red')

plt.title('World\'s Decline in Biocapacity and Increase in Ecological Footprint from 1961-2018')
plt.xlabel('Year')
plt.ylabel('gha per person')
plt.xticks(ticks=year, rotation=70)
plt.grid(True)
plt.grid(color='red',  alpha=0.2, linewidth=2)
plt.legend(labels=['Biocapcity', 'Ecological Footprint'])

# %%
year = np.arange(1961, 2019)
y = EF_DF['Carbon']
fig = plt.figure(figsize=(15, 8))
plt.plot(year, y, color='red')

plt.title('World\'s Carbon Footprint from 1961-2018')
plt.xlabel('Year')
plt.ylabel('gha per person')
plt.xticks(ticks=year, rotation=70)
plt.grid(True)
plt.grid(color='red',  alpha=0.2, linewidth=2)
plt.legend(labels=['Carbon Footprint'])
